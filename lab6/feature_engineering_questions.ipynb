# %% [markdown]
# # Lab 7 - Textual Data Analytics
# Complete the code with TODO tag.
# ## 1. Feature Engineering
# In this exercise we will understand the functioning of TF/IDF ranking. Implement the feature engineering and its application, based on the code framework provided below.
#
# First we use textual data from Twitter.

# %%
import numpy as np
import pandas as pd
from scipy import spatial

data = pd.read_csv('elonmusk_tweets.csv')
print(len(data))
data.head()
# Out:
# 2819
#                    id           created_at  \
# 0  849636868052275200  2017-04-05 14:56:29
# 1  848988730585096192  2017-04-03 20:01:01
# 2  848943072423497728  2017-04-03 16:59:35
# 3  848935705057280001  2017-04-03 16:30:19
# 4  848416049573658624  2017-04-02 06:05:23
#
#                                                 text
# 0  b'And so the robots spared humanity ... https:...
# 1  b"@ForIn2020 @waltmossberg @mims @defcon_5 Exa...
# 2      b'@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                b'Stormy weather in Shortville ...'
# 4  b"@DaveLeeBBC @verge Coal is dying due to nat ...

# %%
# Some data cleaning

# Remove hyperlinks
data['text'] = data['text'].str.replace('http\S+|www.\S+', '', case=False)

# Remove leading 'b'
data['text'] = data['text'].str.replace('^b', '')

# Remove word 'RT'
data['text'] = data['text'].str.replace('RT', '')

data.head()
# Out:
#                    id           created_at  \
# 0  849636868052275200  2017-04-05 14:56:29
# 1  848988730585096192  2017-04-03 20:01:01
# 2  848943072423497728  2017-04-03 16:59:35
# 3  848935705057280001  2017-04-03 16:30:19
# 4  848416049573658624  2017-04-02 06:05:23
#
#                                                 text
# 0            'And so the robots spared humanity ...
# 1  "@ForIn2020 @waltmossberg @mims @defcon_5 Exac...
# 2       '@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 3                 'Stormy weather in Shortville ...'
# 4  "@DaveLeeBBC @verge Coal is dying due to nat g...

# %% [markdown]
# ### 1.1. Text Normalization
# Now we need to normalize text by stemming, tokenizing, and removing stopwords.

# %%
from __future__ import print_function, division
from nltk.stem import PorterStemmer, WordNetLemmatizer
import nltk
nltk.download('punkt')
import string
from nltk.corpus import stopwords
import math
from collections import Counter
nltk.download('stopwords')
import pprint 
pp = pprint.PrettyPrinter(indent=4)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\lucas\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def normalize(document):
    
    # TODO: Remove Punctuation AND tokenize text
    tokenizer = nltk.RegexpTokenizer(r"\w+")
    text = tokenizer.tokenize(document)

    # TODO: Stemming
    porter = PorterStemmer()
    ret = [porter.stem(w) for w in text]
    
    return ret

original_documents = [x.strip() for x in data['text']]

documents = [normalize(d) for d in original_documents]
print(documents[0])
# Out:
# ['and', 'so', 'the', 'robot', 'spare', 'human']

# %% [markdown]
# As you can see that the normalization is still not perfect. Please feel free to improve upon (OPTIONAL), e.g. https://marcobonzanini.com/2015/03/09/mining-twitter-data-with-python-part-2/

# %% [markdown]
# ### 1.2. Implement TF-IDF
# Now you need to implement TF-IDF, including creating the vocabulary, computing term frequency, and normalizing by tf-idf weights.

# %%
import itertools

# Flatten all the documents
flat_list = [word for doc in documents for word in doc]

# TODO: remove stop words from the vocabulary
stop_words = set(stopwords.words('english')) 

words = [w for w in flat_list if w not in stop_words]

# TODO: we take the 500 most common words only
counts = Counter(words)

# Copy our counts into a sorted (decending order) dictionary
vocabulary = {k: v for k, v in sorted(counts.items(), key=lambda item: item[1], reverse=True)}

# Slice the top 500 values
vocabulary = dict(itertools.islice(vocabulary.items(), 500))

# Copy over our words (without values)
vocabulary = [x for x in vocabulary]
vocabulary.sort()

print(vocabulary)
# Out:
# ['0', '000', '1', '10', '100', '11', '1st', '2', '3', '30', '4', '40', '5', '6', '60', '7', '8', '9', 'A', 'AI', 'Am', 'ET', 'I', 'If', 'In', 'It', 'LA', 'My', 'NY', 'No', 'Of', 'S', 'T', 'To', 'US', 'We', 'X', 'abort', 'achiev', 'action', 'actual', 'ad', 'advanc', 'agre', 'aim', 'air', 'alien', 'allow', 'almost', 'alreadi', 'also', 'alway', 'amaz', 'amp', 'ani', 'announc', 'anoth', 'anyth', 'appreci', 'around', 'articl', 'ask', 'attempt', 'auto', 'autopilot', 'away', 'awesom', 'babi', 'back', 'bad', 'badastronom', 'base', 'batteri', 'beauti', 'befor', 'believ', 'best', 'better', 'big', 'bit', 'booster', 'break', 'bring', 'btw', 'build', 'burn', 'busi', 'california', 'call', 'camera', 'canaver', 'cape', 'car', 'carbon', 'care', 'case', 'caus', 'center', 'chang', 'charg', 'check', 'china', 'climat', 'close', 'coast', 'come', 'comment', 'compani', 'competit', 'complet', 'complex', 'confirm', 'consum', 'control', 'cool', 'cost', 'could', 'countri', 'cours', 'cover', 'crazi', 'creat', 'critic', 'current', 'custom', 'data', 'day', 'dealer', 'death', 'deep', 'def', 'definit', 'deliv', 'deploy', 'design', 'detail', 'develop', 'direct', 'doe', 'done', 'door', 'dragon', 'drive', 'droneship', 'due', 'earli', 'earth', 'electr', 'elon', 'elonmusk', 'end', 'energi', 'engin', 'enough', 'entir', 'even', 'ever', 'everi', 'exactli', 'excit', 'expect', 'experi', 'extrem', 'fair', 'falcon', 'far', 'fast', 'featur', 'feel', 'final', 'find', 'fire', 'first', 'fix', 'fli', 'flight', 'forc', 'fredericlambert', 'free', 'fuel', 'full', 'fulli', 'futur', 'ga', 'game', 'gener', 'get', 'gigafactori', 'give', 'go', 'goal', 'goe', 'good', 'got', 'grasshopp', 'great', 'gt', 'ha', 'happen', 'happi', 'hard', 'head', 'hear', 'heard', 'heavi', 'help', 'hi', 'high', 'hit', 'hold', 'home', 'hope', 'hour', 'hous', 'human', 'hw2', 'hyperloop', 'id_aa_carmack', 'idea', 'impact', 'import', 'improv', 'includ', 'increas', 'interest', 'investig', 'issu', 'job', 'keep', 'kid', 'know', 'land', 'last', 'later', 'latest', 'launch', 'law', 'learn', 'leg', 'less', 'level', 'life', 'liftoff', 'like', 'limit', 'line', 'littl', 'live', 'long', 'look', 'lot', 'love', 'low', 'machin', 'made', 'make', 'mani', 'mar', 'matter', 'max', 'may', 'mayb', 'mean', 'media', 'meet', 'mention', 'might', 'mile', 'million', 'min', 'minut', 'mission', 'mode', 'model', 'month', 'moon', 'morn', 'motor', 'move', 'mph', 'much', 'musk', 'must', 'n', 'name', 'nasa', 'need', 'never', 'new', 'news', 'next', 'night', 'non', 'norway', 'number', 'ocean', 'ok', 'one', 'onli', 'open', 'openai', 'oper', 'option', 'orbit', 'order', 'owner', 'pack', 'pad', 'part', 'pass', 'peopl', 'perform', 'person', 'photo', 'physic', 'piec', 'place', 'plan', 'play', 'pleas', 'pod', 'point', 'possibl', 'post', 'power', 'pressur', 'price', 'probabl', 'problem', 'product', 'provid', 'public', 'question', 'race', 'radar', 'rang', 'rate', 'reach', 'read', 'real', 'realli', 'rear', 'reason', 'recommend', 'record', 'reentri', 'releas', 'report', 'requir', 'research', 'return', 'reusabl', 'review', 'ride', 'right', 'risk', 'road', 'rocket', 'roll', 'roof', 'safeti', 'said', 'sale', 'satellit', 'save', 'say', 'seat', 'sec', 'second', 'see', 'seem', 'self', 'sens', 'seri', 'servic', 'set', 'sever', 'ship', 'short', 'show', 'side', 'sign', 'size', 'small', 'softwar', 'solar', 'solarc', 'someth', 'soon', 'sound', 'space', 'space_st', 'spacecraft', 'spaceship', 'spacex', 'speed', 'stage', 'start', 'state', 'station', 'still', 'stop', 'stori', 'success', 'suggest', 'super', 'supercharg', 'support', 'sure', 'system', 'take', 'talk', 'target', 'tax', 'team', 'technolog', 'term', 'tesla', 'teslamotor', 'test', 'texa', 'thank', 'thi', 'thing', 'think', 'though', 'thought', 'three', 'thrust', 'thruster', 'time', 'tmrw', 'today', 'tomorrow', 'tonight', 'took', 'top', 'total', 'track', 'travel', 'tri', 'trip', 'true', 'turn', 'tweet', 'two', 'unveil', 'updat', 'upgrad', 'upper', 'us', 'use', 'v', 'vehicl', 'veloc', 'veri', 'version', 'vertic', 'v ...

# %% [markdown]
# ## TF (Term Frequency)
#
# The number of times a term appears in a document

# %%
def tf(vocabulary, documents):
    matrix = [0] * len(documents)
    for i, document in enumerate(documents):
        counts = Counter(document)
        matrix[i] = [0] * len(vocabulary)
        for j, term in enumerate(vocabulary):
            matrix[i][j] = counts[term]
    return matrix

tf = tf(vocabulary, documents)
np.array(vocabulary)[np.where(np.array(tf[1]) > 0)], np.array(tf[1])[np.where(np.array(tf[1]) > 0)]
# Out:
# (array(['base', 'exactli', 'tesla', 'x80', 'xa6', 'xe2'], dtype='<U15'),
#  array([1, 1, 1, 1, 1, 1]))

# %% [markdown]
# ## IDF
#
# log (Number of docs / Number of docs that contain a term)

# %%
def idf(vocabulary, documents):
    """TODO: compute IDF, storing values in a dictionary"""
    idf = {}
    
    N = len(documents)
    
    
    for vocab_w in vocabulary:
        times_appeared = 0
        
        # Find how many documents have that word
        for doc in documents:
            for doc_w in doc:
                if vocab_w == doc_w:
                    times_appeared += 1
                    break
            
        
        # Apply our calculation
        idf[vocab_w] = math.log(N / times_appeared)
    
    return idf

idf = idf(vocabulary, documents)
[idf[key] for key in vocabulary[:5]]


# Printing our some of the IDF scores
for i, k in enumerate(idf):
    print("(", k ,"|", idf[k],")")
    if i > 30:
        break
# Out:
# ( 0 | 4.417776966497951 )
# ( 000 | 5.305080161498854 )
# ( 1 | 3.478229372459529 )
# ( 10 | 4.5429401094519575 )
# ( 100 | 5.053765733217948 )
# ( 11 | 5.459230841326113 )
# ( 1st | 4.808643275184963 )
# ( 2 | 3.754482749087687 )
# ( 3 | 3.513320692270799 )
# ( 30 | 4.853095037755796 )
# ( 4 | 4.447629929647633 )
# ( 40 | 5.305080161498854 )
# ( 5 | 3.8836944805676934 )
# ( 6 | 4.447629929647633 )
# ( 60 | 4.853095037755796 )
# ( 7 | 5.053765733217948 )
# ( 8 | 4.611932980938908 )
# ( 9 | 3.537418243849859 )
# ( A | 4.1829373754205506 )
# ( AI | 4.611932980938908 )
# ( Am | 4.417776966497951 )
# ( ET | 4.766083660766167 )
# ( I | 2.4974001194478026 )
# ( If | 4.333219578469889 )
# ( In | 4.766083660766167 )
# ( It | 3.4897901948606047 )
# ( LA | 4.611932980938908 )
# ( My | 4.280575844984466 )
# ( NY | 5.546242218315742 )
# ( No | 4.115496094625017 )
# ( Of | 5.379188133652576 )
# ( S | 2.838192017213532 )

# %%
def vectorize(document, vocabulary, idf):
    vector = [0]*len(vocabulary)
    counts = Counter(document)
    for i,term in enumerate(vocabulary):
        vector[i] = idf[term] * counts[term]
    return vector

document_vectors = [vectorize(s, vocabulary, idf) for s in documents]
np.array(vocabulary)[np.where(np.array(document_vectors[1]) > 0)], np.array(document_vectors[1])[np.where(np.array(document_vectors[1]) > 0)]
# Out:
# (array(['base', 'exactli', 'tesla', 'x80', 'xa6', 'xe2'], dtype='<U15'),
#  array([5.54624222, 4.47840159, 2.09481271, 2.67627933, 3.24365713,
#         2.62112751]))

# %% [markdown]
# ### 1.3. Compare the results with the reference implementation of scikit-learn library.

# %% [markdown]
# Now we use the scikit-learn library. As you can see that, the way we do text normalization affects the result. Feel free to further improve upon (OPTIONAL), e.g. https://stackoverflow.com/questions/36182502/add-stemming-support-to-countvectorizer-sklearn

# %%
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel

tfidf = TfidfVectorizer(analyzer='word', ngram_range=(1,1), min_df = 1, stop_words = 'english', max_features=500)

features = tfidf.fit(original_documents)
corpus_tf_idf = tfidf.transform(original_documents) 

sum_words = corpus_tf_idf.sum(axis=0)
words_freq = [(word, sum_words[0, idx]) for word, idx in tfidf.vocabulary_.items()]
print(sorted(words_freq, key = lambda x: x[1], reverse=True)[:5])
print('testla', corpus_tf_idf[1, features.vocabulary_['tesla']])
# Out:
# [('tesla', 101.90986835463575), ('model', 79.77144565643432), ('spacex', 75.61689890838036), ('yes', 65.62323278091372), ('teslamotors', 64.90757497311142)]
# testla 0.3393247403223787

# %% [markdown]
# ### 1.4.  Apply TF-IDF for information retrieval
# We can use the vector representation of documents to implement an information retrieval system. We test with the query $Q$ = "tesla nasa"

# %%
lst = [0.0, 0.01, 0.02, 0.0, 0.1, 0.0003]
sorted(lst)
# Out:
# [0.0, 0.0, 0.0003, 0.01, 0.02, 0.1]

# %%
def cosine_similarity(v1,v2):
    """TODO: compute cosine similarity"""
    #sumxx, sumxy, sumyy = 0, 0, 0
    
    result = 1 - spatial.distance.cosine(v1, v2)
    
    return result

def search_vec(query, k, vocabulary, stemmer, document_vectors, original_documents):
    q = query.split()
    q = [stemmer.stem(w) for w in q]
    
    query_vector = vectorize(q, vocabulary, idf)
    
    
    # TODO: rank the documents by cosine similarity
    scores = []
    
    for k, document_vector in enumerate(document_vectors):
        sim = cosine_similarity(query_vector, document_vector)
        score = [sim, k]
        scores.append(score)
    
    # BUG: Not sorting properly
    scores = sorted(scores, key=lambda item: item[0], reverse=True)
    
    print('Top-{0} documents'.format(k))
    for i in range(k):
        print(i, original_documents[scores[i][1]])

query = "tesla nasa"
stemmer = PorterStemmer()
search_vec(query, 5, vocabulary, stemmer, document_vectors, original_documents)
# Out:
# Top-2818 documents
# 0 '@ashwin7002 @NASA @faa @AFPAA We have not ruled that out.'
# 1 ' @jehldavid: Beautiful up to date album of @SpaceX Dragon spacecraft photos released by @NASA. @elonmusk
# 2 "@ForIn2020 @waltmossberg @mims @defcon_5 Exactly. Tesla is absurdly overvalued if based on the past, but that's irr\xe2\x80\xa6
# 3 'And so the robots spared humanity ...
# 4 '@waltmossberg @mims @defcon_5 Et tu, Walt?'
# 5 '@business Glad to have Tencent as an investor and advisor to Tesla'
# 6 'Made today on Tesla sketch pad
# 7 '@nddugan Yup'
# 8 " @Shkottt: @elonmusk my Tesla Roadster is the best car i've ever had"
# 9 " @RicardoTwumasi: @elonmusk My Tesla Model S is the best car I've ever had
# 10 ' @arctechinc: @elonmusk we believe so much in Tesla and its goals we have a 100D Model S and 90D Model X and love both. Thank you!
# 11 " @Herifin_teki: @elonmusk My lil monster Tesla Model X is the best car I've ever used. Thank you Elon. \xe2\x9d\xa4\xef\xb8\x8f"
# 12 'Stormy weather in Shortville ...'
# 13 "@DaveLeeBBC @verge Coal is dying due to nat gas fracking. It's basically dead."
# 14 "@Lexxxzis It's just a helicopter in helicopter's clothing"
# 15 "@verge It won't matter"
# 16 '@SuperCoolCube Pretty good'
# 17 "Why did we waste so much time developing silly rockets? Damn you, aliens! So obtuse! You have all this crazy tech, but can't speak English!?"
# 18 'Technology breakthrough: turns out chemtrails are actually a message from time-traveling aliens describing the secret of teleportation'
# 19 " @OpenAI: We've created the world's first Spam-detecting AI trained entirely in simulation and deployed on a physical robot:
# 20 ' @ProfBrianCox: This is extremely important from @elonmusk and @SpaceX - reusable rockets bring us MUCH closer to becoming a spacefaring\xe2\x80\xa6'
# 21 '@adamsbj Def P100D with Ludicrous+, although the rocket starts going a lot faster after that'
# 22 '@BadAstronomer We can def bring it back like Dragon. Just a question of how much weight we need to add.'
# 23 '@tesla_addict @TeslaMotors Working on it'
# 24 "@jasonlamb Looks like it could do 20% more with some structural upgrades to handle higher loads. But that's in fully expendable mode."
# 25 '@cheron A lot'
# 26 '@Cardoso Silliest thing we can imagine! Secret payload of 1st Dragon flight was a giant wheel of cheese. Inspired b\xe2\x80\xa6
# 27 '@redletterdave Good point, odds go from 0% to &gt;0% :)'
# 28 'Falcon Heavy test flight currently scheduled for late summer'
# 29 'Considering trying to bring upper stage back on Falcon Heavy demo flight for full reusability. Odds of success low, but maybe worth a shot.'
# 30 '@oxfordteddy Browser is already a little better. Kernel and browser update in prob 6 weeks or so (lots of underlyin\xe2\x80\xa6
# 31 ' @SpaceX: More photos from today\xe2\x80\x99s Falcon 9 launch and first stage landing \xe2\x86\x92
# 32 '@BadAstronomer @SpaceX Thanks Phil!'
# 33 'Incredibly proud of the SpaceX team for achieving this milestone in space! Next goal is reflight within 24 hours.'
# 34 ' @SpaceX: Falcon 9 first stage has landed on Of Course I Still Love You \xe2\x80\x94 world\xe2\x80\x99s first reflight of an orbital class rocket.'
# 35 ' @SpaceX: ~60 minutes until launch window for SES-10 opens. All systems and weather are go. Watch here \xe2\x86\x92
# 36 ' @SpaceX: Falcon 9 and SES-10 vertical on Kennedy Space Center\xe2\x80\x99s historic Pad 39A. Launch window opens at 6:27pm EDT, 10:27pm UTC.
# 37 'If you just downloaded V8.1, tap the the T on center screen three times'
# 38 '@drmanejwala @arctechinc On center screen. Also, center screen *will* show speed as an overlay that changes opacity according to relevance.'
# 39 '@danahull Very few. We have yet to do a China (or Europe) launch of Model 3.'
# 40 '@nickg_uk @chouky02 No'
# 41 "@nickg_uk @chouky02 You won't care"
# 42 '@NakatomiTim What gave me away?'
# 43 '@nickg_uk No'
# 44 'Here is the latest SpaceX travel ad for the flight around the moon &amp; into deep space. Maybe needs a few edits ...
# 45 'Long Neuralink piece coming out on @waitbutwhy in about a week. Difficult to dedicate the time, but existential risk is too high not to.'
# 46 " @OpenAI: New research release: overcoming many of Reinforcement Learning's limitations with Evolution Strategies:
# 47 '@erikhaaland We cannot make all country versions simultaneously or the production start would be a disaster. You would get first in Norway.'
# 48 '@Isabelle_Kent Yes'
# 49 '@D1sneyNut Yes'
# 50 '@nickbaum I believe so'
# 51 '@Mr_Ewe_Guy Oh so little faith'
# 52 '@kryniog The shorter wheelbase only allows for a 75 kWh pack in Model 3 at current cell/module energy densities'
# 53 ' @PokerVixen: @elonmusk I\'m so unbelievably happy with my Model S. When people ask if l like it I respond "No, I love it! \xf0\x9f\x98\x8d it\'s amazing!\xe2\x80\xa6'
# 54 ' @RH_Way: @elonmusk Our 85 hit the guardrails at well over 160km/h. Tessi absorbed impact, wife and baby are ok. Best car ever &amp; Member o\xe2\x80\xa6'
# 55 '@ToddGerkens Yeah'
# 56 '@HolsMichael Start taking orders in April'
# 57 '@dr_angus Yeah, probably a year from now. S will still win on acceleration though, due to having more space for a larger battery.'
# 58 ' @morrisonbrett: @elonmusk First batch Model S P85D for me, Grey. Signature Model X P90D for wife, Triple White. Best vehicles in the wor\xe2\x80\xa6'
# 59 '@akaWrecks @ckalapala Only Model S will have the seven seater option, more cargo space, plus higher range, accelera\xe2\x80\xa6
# 60 '@CamKode The Model S produced today is arguably version 4. Let me put it this way: it is the car I will keep drivin\xe2\x80\xa6
# 61 '@BlueBowles If fate is on our side, it will be amazing. Will talk about that in detail next week.'
# 62 '@juanmlemao No problem :)'
# 63 '@DJBurges Should be summer next year. Sorry, really wish we could get RHD done sooner. We truly are working as fast as we can.'
# 64 '@faultywarrior @matt_trulli @FredericLambert @TimShelton @JimPengelly Let me just go fetch my magic wand ...'
# 65 '@TimShelton @FredericLambert @JimPengelly First in line for dual motor as soon as we can make it, which is probably in 6 to 9 months.'
# 66 '@meangene2030 Damn straight we do! Coming with 8.1 next week.'
# 67 'First drive of a release candidate version of Model 3
# 68 '@Trojan81 Tues/Wed'
# 69 '@Greg525 How about now?'
# 70 '@karaswisher I am not. This bill changes almost nothing about what NASA is doing. Existing programs stay in place a\xe2\x80\xa6
# 71 ' @NASA: LIVE NOW: Find out what experiments are headed to @Space_Station on the next @SpaceX launch:
# 72 'Tesla P100D put to the test by Drag Times
# 73 'Comprehensive study by Autolist shows that a Tesla retains its value far better than gasoline sedans\n
# 74 " @TeslaMotors: Tesla Powerpacks to help solve Los Angeles peak energy demand with world's biggest battery storage project
# 75 ' @verge: Tesla is building an 80MWh battery pack to supply LA with power
# 76 'Will do some press Q&amp;A on Autopilot post at 11am PDT tmrw and then publish at noon. Sorry about delay. Unusually difficult couple of weeks.'
# 77 "@LewisChandlerDN nope, it wasn't me"
# 78 'Support &amp; advice from @NASA, @FAA, @AFPAA &amp; others much appreciated. Please email any recordings of the event to report@spacex.com.'
# 79 'Writing post now with details. Will publish on Tesla website later today.'
# 80 ' @TechCrunch: Tesla Autopilot 8.0 uses radar to prevent accidents like the fatal Model S crash
# 81 'Tesla Model S loses 28% after 50k miles, a Mercedes S-Class will lose 38%, a BMW 7-series will lose 40%, and an Audi A8 will lose 41%.'
# 82 'Preview of the @SpaceX interplanetary transport system at @IAC2016\n
# 83 "@JonasPolsky @schellgames that's a great one"
# 84 '@andyzalk sounds like the right name for the rocket booster'
# 85 '@LarryMasters778 That is my favorite fictional spaceship. Powered by improbability!'
# 86 '@TheMikeBartley yeah!'
# 87 "Maybe Ultimate Spaceship, Version 2? Mostly because it is not the ultimate and there isn't a version 1."
# 88 'I love the suggestions!'
# 89 '@kzmakino sounds about right'
# 90 'Turns out MCT can go well beyond Mars, so will need a new name\xe2\x80\xa6'
# 91 '@asunshinegreene yes'
# 92 "@danielringdahl @P100D won't affect performance"
# 93 '@vicentes @EdibleApple Hoping to start WW rollout of 8.0 on Wednesday if no last minute issues discovered.'
# 94 '@danielringdahl @P100D Glad you like it! I think we will probably stop at 100 kWh on battery size.'
# 95 ' @ycombinator: .@sama interviewed @elonmusk about the future
# 96 ' @sama: New @OpenAI building!
# 97 'Turns out ExxonMobil not 100% forthcoming about climate change  via @BW'
# 98 'Scientists: Earth Endangered by New Strain of Fact-Resistant Humans  via @BorowitzReport'
# 99 'Climate change explained in comic book form by xkcd \n
# 100 ' @TeslaMotors: Upgrading Autopilot: seeing the world in radar
# 101 'Thoughtful Op-ed in Space News much appreciated
# 102 ' @SpaceX: If you have audio, photos or videos of our anomaly last week, please send to report@spacex.com. Material may be useful for inve\xe2\x80\xa6'
# 103 "@abadcliche Most likely true, but we can't yet find it on any vehicle sensors"
# 104 'Will get back to Autopilot update blog tomorrow.'
# 105 'Particularly trying to understand the quieter bang sound a few seconds before the fireball goes off. May come from rocket or something else.'
# 106 'Important to note that this happened during a routine filling operation. Engines were not on and there was no apparent heat source.'
# 107 'Still working on the Falcon fireball investigation. Turning out to be the most difficult and complex failure we have ever had in 14 years.'
# 108 "@waitbutwhy It's been a little crazy lately"
# 109 '@scrappydog yes. This seems instant from a human perspective, but it really a fast fire, not an explosion. Dragon would have been fine.'
# 110 'Finishing Autopilot blog postponed to  end of weekend'
# 111 'Loss of Falcon vehicle today during propellant fill operation. Originated around upper stage oxygen tank. Cause still unknown. More soon.'
# 112 '@Lockyep Not allowed, according to HK regulations. Happy to do it if regs change.'
# 113 'We need to do one more minor rev on 8.0 and then will go to wide release in a few weeks'
# 114 'Major improvements to Autopilot coming with V8.0 and 8.1 software (std OTA update) primarily through advanced processing of radar signals'
# 115 '@newscientist uh oh'
# 116 'Correlation is not causality or ... is it?
# 117 ' @NASA: We ordered second @SpaceX mission to send U.S. astronauts to @Space_Station:  #LaunchAmerica
# 118 ' @Reuters: Tesla gets vote of confidence from a top investor at Fidelity
# 119 " @business: Even Tesla's SUV is now faster than a Lamborghini
# 120 ' @MattHardigree: The Tesla Model S P100D is now faster in a straight line than it would be if you dropped it out of a plane.'
# 121 " @CNBC: A rare look inside Tesla's 'gigafactory'
# 122 'Some good guessing by @Jalopnik. The Tesla Minibus will be built on a Model X chassis. People density potential is surprisingly high.'
# 123 '
# 124 'Tesla Master Plan, Part Deux\n
# 125 ' @TeslaMotors: Mystery shoppers rate Tesla #1 on the EV shopping experience
# 126 'Post should go live on Tesla website around 5pm'
# 127 'Tesla product announcement at noon California time today'
# 128 '@RoadandTrack @TeslaMotors Model Y (compact SUV) off Model 3 chassis. Tesla Bus/Minibus/Spacebus off Model X.'
# 129 '@Skate_a_book Yes. Model S will always be the fastest Tesla until next gen Roadster, which is a few years away.'
# 130 "Have to focus on tonight's @SpaceX launch. Will post Tesla (master) product plan afterwards."
# 131 ' @verge: Millions of Tesla battery cells are powering thousands of LA homes
# 132 '@luciojr All Tesla cars built since Oct last year will be capable of self-driving as software improves'
# 133 'Great rebuttal by a Tesla owner to those calling for Autopilot to be disabled. Was written with zero input from us.
# 134 ' @ElectrekCo: Tesla Model S becomes highest rated sedan on new \xe2\x80\x98Amazon Vehicles\xe2\x80\x99
# 135 '@danahull Jerome is driving Tesla Semi &amp; doing a great job with his team. At Daimler, he led their most successful semi truck program ever.'
# 136 ' @kytv:  #Tesla @elonmusk Branson man thanks self-driving car for driving to hospital during medical emergency. #T\xe2\x80\xa6'
# 137 ' @TeslaMotors: What a Tesla looks like after 100,000 Miles, a 48 State Road trip, 500 Uber Rides, 20 Rentals &amp; more @SteveSasman
# 138 'Am noticing that many people think Model 3 is the "next version" of a Tesla, like iPhone 2 vs 3. This is not true.'
# 139 '@FredericLambert It still has one display'
# 140 " @danieltadros: @bobbykansara @elonmusk @MrThorman My model S is the best car I've ever had !!"
# 141 '@VoltzCoreAudio Nothing majorly new that a consumer would notice. Lots of new tech in the design and production process though.'
# 142 '@arctechinc The more autonomous a car is, the less dash info you need. How often do you look at the instrument pane\xe2\x80\xa6
# 143 '@asimo3089 How about the video we just took of the first Model 3 release candidate drive?'
# 144 ' @bobbykansara: @MrThorman @elonmusk My Model X is the greatest thing I have ever purchased. Period.'
# 145 '@trabru Yup, machine arrives next month and we start digging the tunnel!'
# 146 '@oakhaller I think so'
# 147 '@FredericLambert @JimPengelly No, we are minimizing configuration complexity to keep the production ramp on schedul\xe2\x80\xa6
# 148 "@jDaz Because I was a dumb idiot and didn't realize at the time that it would cause confusion"
# 149 '@timothymjr Tues/Wed next week'
# 150 '@JimPengelly Yes, but not until next year'
# 151 '@AlSaibie Yes. Hardware already on all production S and X cars.'
# 152 '@theKen_Miller Sorta. Model 3 is like a BMW 3 series or Audi A4. Model S is like BMW 5 and 6 series, but much faste\xe2\x80\xa6
# 153 '@varunfatehpuria Oh Model Y is coming too in a few years. Kinda have to.'
# 154 '@swindeez Definitely'
# 155 'Model 3 was going to be called Model E, for obvious dumb humor reasons, but Ford sued to block it, so now it is S3X. Totally different :)'
# 156 '@TimBeiko Yes'
# 157 'Model 3 is just a smaller, more affordable version of Model S w less range &amp; power &amp; fewer features. Model S has more advanced technology.'
# 158 '@macwalterslives Looking forward to playing the game with my kids!'
# 159 "@aaronpaul_8 I used to be one. You're welcome. Trying my best, at least. Hope it's a bit useful."
# 160 "@nextspaceflight @inversedotcom Just because I'm building a spaceship to get back to my home planet doesn't mean I'm an alien"
# 161 '@lennart375 @inversedotcom The number of extinct single planet civilizations probably exceeds live civs by at least\xe2\x80\xa6
# 162 '@phirate Probably. Either that, simulation, great filter or they are very, very subtle.'
# 163 "@Nites I hope that didn't work"
# 164 '@Nites ~spawn npc.alien'
# 165 'Where are the #%*&gt; aliens?
# 166 '@wouterhuijs Looks like Tues/Wed for 8.1 release'
# 167 "@x17online Except that isn't actually my house ..."
# 168 '@karaswisher Perhaps there will be some future bill that makes a difference for Mars, but this is not it.'
# 169 " @ryanrossuk: @elonmusk Hope you like my Model X customer story. You're something of a hero of mine. Never give up and thank you!
# 170 ' @SpaceX: Recovery teams en route to Dragon.
# 171 " @SpaceX: More photos from today's Falcon 9 launch \xe2\x86\x92
# 172 ' @SpaceX: Successful deployment of @EchoStar XXIII to a Geosynchronous Transfer Orbit confirmed.
# 173 ' @SpaceX: Back live for final burn and satellite deployment \xe2\x86\x92
# 174 ' @SpaceX: Liftoff!
# 175 '@CapnJesus @Lurpatron @MKBHD @jakerawr 3 is a great car, but definitely Model S'
# 176 '@kyleugh Good point'
# 177 "@PriyancaFord I wish. It's so annoying."
# 178 '@AndreElijah Ok'
# 179 '
# 180 "SpaceX could not do this without NASA. Can't express enough appreciation.
# 181 'Excellent Tesla Model X review
# 182 '@mcannonbrookes Tesla will get the system installed and working 100 days from contract signature or it is free. That serious enough for you?'
# 183 '@mcannonbrookes $250/kWh at the pack level for 100MWh+ systems. Tesla is moving to fixed and open pricing and terms for all products.'
# 184 'Finally, an explanation for daylight savings that makes sense ...
# 185 "@BizbuilderUSA @mcannonbrookes It's been a bear to get done, but prob 10 days or so, depending on full speed autosteer test results"
# 186 "@Legit_bacon @mcannonbrookes Looking forward to it. I know it's cliche, but LotR is my favorite book ever :) Want t\xe2\x80\xa6
# 187 '@5AllanLeVito @mcannonbrookes @VGroysman Sure. Just check out my prior tweet on pricing ($250 kWh at pack level). W\xe2\x80\xa6
# 188 '.@mcannonbrookes Can only happen with your support, and working closely with key govt and utility leaders who are s\xe2\x80\xa6
# 189 'Just wanted to write a note of appreciation to the many Australians who came out in support of the battery plan, especially @mcannonbrookes'
# 190 '@ah_pton16 I love Wikipedia. Just gets better over time.'
# 191 '@JMMZHerrera Answer is complex for electric motors. We use an AC induction motor fed by a DC pack thru an IGBT inve\xe2\x80\xa6
# 192 '@williamwinters High voltage DC is for sure the best way to transmit electricity over long distances. Good explanat\xe2\x80\xa6
# 193 'Ironically, direct current is the right approach today, even though alternating was right in the past. Solar power &amp; electronics both DC.'
# 194 "You're most welcome. Very exciting to discuss the future of electricity. Renewables + storage arguably biggest disr\xe2\x80\xa6
# 195 '@mcannonbrookes Just spoke with @JayWeatherill, Premier of South Australia. Very impressed. Govt is clearly committ\xe2\x80\xa6
# 196 '@shails Yes, but shipping, taxes/tariffs and installation labor vary by country, as those costs are beyond our control'
# 197 '@Zedd Will send you one'
# 198 '@SimonaKitzu Self-hatred'
# 199 'Thanks JJ!'
# 200 ' @TeslaMotors: Project Loveday
# 201 "Thank you for the lovely letter. That sounds like a great idea. We'll do it!
# 202 "@jamesatbuzz This is not true. TM works for a lot of people and that's great, but I've maybe done it 7 or 8 times ever."
# 203 'Fly me to the moon ... Ok\n
# 204 'SpaceX announcement tomorrow at 1pm PST'
# 205 '@MacTechGenius of course'
# 206 '@DueDiamond maybe one of those too'
# 207 'Roller coasters are awesome'
# 208 '@johnpaulbrewer Something on a tristate border might work. Gigafactory plus nearby supporting supply chain needs a very large workforce.'
# 209 '@donbarbieri @GreenCarReports Good chance it will'
# 210 '@davidshepardson @BW @ATT @ToysRUs Exactly :)'
# 211 "@meganmurp @ChrisFaile @BW I didn't pose for it (hopefully that's obvious) or want me on cover. Tunnel boring machine pic wd be way better"
# 212 '@adrianvolts Minor improvements update this weekend. High speed autosteer in about two weeks.'
# 213 'Just posted a video
# 214 '
# 215 'Baby came back
# 216 ' @SpaceX: Falcon 9 first stage has landed at LZ-1'
# 217 '@mattnewby no'
# 218 ' @NASA: Right on schedule, solar arrays have been deployed on @SpaceX #Dragon cargo spacecraft. Watch:
# 219 '@Xuan_Thai System was green for launch. I called it off.'
# 220 '@spacecom They are often right, but, in this case, we have already retired so much R&amp;D risk on Dragon 2, that I feel very confident of 2018.'
# 221 '@zperrin99 Uses high pressure bleed off the fuel side (RP-1 kerosene) turbopump, so no dedicated pump or fluid needed'
# 222 "Btw, 99% likely to be fine (closed loop TVC wd overcome error), but that 1% chance isn't worth rolling the dice. Better to wait a day."
# 223 '@VRGTech @Floydilicious They are doing India proud'
# 224 " @SpaceX: Targeting Feb. 18 for Dragon's next resupply mission to the @Space_Station \xe2\x80\x94 our 1st launch from LC-39A at @NASA's Kennedy Spac\xe2\x80\xa6"
# 225 " @NASA: Hear from experts at 5pm ET about the status of tomorrow's 10:01am ET @SpaceX cargo launch to @Space_Station:
# 226 '@RusulAlrubail @MarkRuffalo @guardian Please check your facts. Tesla and SpaceX joined as soon as we received the filing, which was Monday.'
# 227 "@jovanik21 Also, Tesla service can remove front trunk liner if you don't use it and improve performance further"
# 228 '@SEACityLight @Nas2four Sounds like the Tesla Powerwall (consumer) and Powerpack (utility/commercial) might be useful'
# 229 'Congrats to the Tesla owner who sacrificed damage to his own car to bring a car with an unconscious driver safely to a stop!'
# 230 ' @TeslaMotors: Supercharger availability is now displayed on your Tesla touchscreen so you can see how many stalls are open before you ar\xe2\x80\xa6'
# 231 'In appreciation, Tesla is providing all repair costs free of charge and expedited.
# 232 'Production Tesla Model S P100DL sets Motor Trend all-time world record to 60 mph in 2.27 sec
# 233 '@Zybbby Not obviously related to the (very tiny) helium leak, but also not out of the question'
# 234 "If this is the only issue, flight would be fine, but need to make sure that it isn't symptomatic of a more significant upstream root cause"
# 235 'All systems go, except the movement trace of an upper stage engine steering hydraulic piston was slightly odd. Standing down to investigate.'
# 236 ' @SpaceX: 1 hour from launch of Falcon 9 &amp; Dragon to @Space_Station. Rocket &amp; weather are go. Launch at 10:01am ET, 15:01 UTC
# 237 'Counting down to the first SpaceX launch from the Apollo 11 launch pad tomorrow morning (webcast\xe2\x80\xa6
# 238 "spacex's photo
# 239 'Provided Dragon 2 demo missions go well, SpaceX is highly confident of being able to fly US astronauts in 2018
# 240 'Looks like we are go for launch. Added an abort trigger at T-60 secs for pressure decay of upper stage helium spin start system.'
# 241 'Investigating a (very small) leak in the upper stage. If ok, will launch tomorrow.
# 242 "@emenietti @chafkin Yes, but only deep in solid rock, where the walls are self-supporting and concrete reinforcements arguably aren't needed"
# 243 "@sc00bs It's much easier to do the CGI that way"
# 244 'Daylight rocket launch &amp; landing at the Cape this weekend. Will be the 1st SpaceX flight from the Apollo launch pad.
# 245 '@PhoebeColeman I used that one :)'
# 246 "Ok, what are some good ones? Will have to meter these out. Hopefully, kids can't die from groaning too much."
# 247 '@osiris26 You may come to regret that request :)'
# 248 '@LittleDovah Yeah, exactly. So that makes it cool, right!?'
# 249 '@Floydilicious Yeah, awesome achievement by ISRO. Very impressive!'
# 250 'Apparently, there is this thing called "Dad jokes" and I make them'
# 251 "@LudwigMorelos You're right, I can't hide any more! I am Irony Man..."
# 252 '@Samcornwell they were earlier drafts that I accidentally published. I said the same thing a week already.'
# 253 '@lollieshopMOM Best place to watch is on the Cape causeway'
# 254 'Falcon 9 rocket now vertical at Cape Canaveral on launch complex 39-A. This is the same launch\xe2\x80\xa6
# 255 '@accohen @MeganGeuss @arstechnica Exactly. What this person said is untrue.'
# 256 '@dknisely of course it will'
# 257 '@SundalJ Should all be uploaded by next month'
# 258 '@sureal808 Motor Trend could only achieve 2.4 sec when they tested the Porsche 918'
# 259 "@VoltzCoreAudio I don't know what make you think that's a rocket. It's completely covered in a tarpaulin..."
# 260 'George Schultz and Jim Baker article in @WSJ regarding a carbon tax
# 261 '@BatlaG yes'
# 262 '@goel_ishan Hoping for summer this year'
# 263 '@mdcdave yes, altitude improves performance for electric. Opposite of combustion cars.'
# 264 "@jovanik21 @Veidit No, will be lower. Wheelbase can't fit 100."
# 265 '@Veidit No plans to take X, S (or 3) above 100 kWh. Semi necessarily and pickup truck maybe will go above.'
# 266 '@jovanik21 Take out the floor mats and its 2.27. MT said everything had to be standard production.'
# 267 '@quick_pi yes'
# 268 'Signing off now. That was more than enough Twitter trouble for one morning!'
# 269 ' @SteveCase: I agree:
# 270 '@qriosity_ @MacTechGenius No rare earth metals in battery'
# 271 '@camdtor @trylks Almost ready'
# 272 '@MacTechGenius App update is about two weeks out. Linux kernel and browser update probably a month or so. HW2 Autopilot has priority.'
# 273 '@FredericLambert Yes, but Model 3 is the overwhelming priority'
# 274 '@clay_ellis I will post an article he wrote half a century ago about flying through Africa and Asia in his plane. One of my favorite things.'
# 275 '@christesla @FredericLambert Almost there. We are just being very careful with the rollout.'
# 276 "@trylks A lot of terrible things could happen in four years of extremism. Do you really want another war? That's where extremism leads."
# 277 '@FredericLambert Yeah, it is hard to convey complex ideas in 140 chars and tone is lost in text'
# 278 '@CycleTrades @rtoro20 People should push to have as many moderates advising the President as possible. Blind hate is never the right answer.'
# 279 '@Wise1919 @FredericLambert Rolling out a new update today.'
# 280 '@recipher We should try our best'
# 281 '@iamDeveloper Really? Ok, I will work harder on thinking first and tweeting second. Sorry for anything thoughtless.'
# 282 '@martinengwicht @FredericLambert I just had three coffees :)'
# 283 '@thelogicbox @IanrossWins Mars is critical for the long-term survival of humanity and life on Earth as we know it'
# 284 '@seanbroswag @FredericLambert Numeric'
# 285 '@B0Turner Gravimetric energy density of batteries and achieving a high cell mass fraction'
# 286 "@Travelingmom23 I love Canada! I'm half Canadian. My Mom was born in Regina. My grandfather (her Dad) was American, born in Minnesota."
# 287 '@FredericLambert Me too. I hope to get back to regularly scheduled programming soon ...'
# 288 "@brendangage I agree, great country! Looking forward to taking my kids for a visit. I've heard it is incredibly beautiful."
# 289 '@rtoro20 Really? I already have both feet in my mouth and am levitating on my own idiocy...'
# 290 '@DaringKid True. Me being one of them :)'
# 291 '@marcelsalathe Not perfect &amp; cd be better, but 10th out of 200+ countries with only a 0.08 diff to "1st" place means it\'s essentially on par'
# 292 '@andresantoniop Fair point, sorry'
# 293 'Activists should be pushing for more moderates to advise President, not fewer. How could having only extremists advise him possibly be good?'
# 294 '@RealPhillipPoon Needs a major overhaul'
# 295 '@BenCam137 @FifthRocket Exactly'
# 296 '@AanstadGard Norway is great on all levels. Love Norway!'
# 297 '@BullFlags Yeah. And Twitter is a hater Hellscape.'
# 298 '@W4AS Good grief, I\'m not "working" for Trump. I\'m trying to provide advice that helps take things in a more positive direction.'
# 299 "@BitterMercy @CallumK24 Actually, I think it's kinda cool :)"
# 300 "@EricHaegler @iLexomat Isn't that basically like having a jury of peers? That is a default option in the US."
# 301 "@vladsavov Those countries have strong justice systems, but I'd put them roughly on par with US. That rating system conflates many factors."
# 302 '@FifthRocket Did you read my tweets? I attacked it hard. Did not defend.'
# 303 "@KENEMONICS You're right. Politics is a no-win situation. Somebody is going to hate what you say no matter what that is."
# 304 "@martinengwicht Also good. There are several that are on par with US. Just don't think any are better. People confuse laws with courts."
# 305 '@paulvankeep Mostly anti-drug laws'
# 306 '@zgiarrizzo Exactly'
# 307 '@TheLAAdams The laws need to change. Judges are responsible for evaluating whether an action breaks the law, not making law.'
# 308 '@humplik The remedy for that is changing the law'
# 309 "@CallumK24 Ok, but what's up the wigs?"
# 310 "@iLexomat There are many good legal systems on par with US. Just don't know any that are better."
# 311 '@Biesseman True!'
# 312 "Many in America don't realize how proud they should be of the legal system. Not perfect, but nowhere is the cause of justice better served."
# 313 ' @TeslaMotors: Honored to receive Best Car Award for the third year in a row in Germany. Thank you to all 124,000 of you who voted!
# 314 'Walking down the street and saw this
# 315 '@ChrisJCav Maybe my favorite mug ever'
# 316 '@nintendomaniac @alext4627 I wish!'
# 317 "@OldManRiver1800 Then so be it. I'd rather do what I believe is right, than do what appears right simply to avoid criticism."
# 318 '@bonnienorman @advandermeer Wow, cool!'
# 319 'Minecraft
# 320 " @TeslaMotors: Meet the utility grid of the future. Tesla's Powerpack installation at @SCE's substation will reduce the LA Basin's relian\xe2\x80\xa6"
# 321 "@alext4627 That's exactly what I thought. Love Half-Life."
# 322 '@ana_lontana Nuances are important :)'
# 323 'Rainbows, unicorns and electric cars
# 324 '26 ft diameter tunnel running 2 miles under D.C.
# 325 "@eveegdmann Really don't want to get in politics. I just want to help invent and develop technologies that improve lives. Feels so bizarre."
# 326 '@DanielleBloeme Yes, for now, but this should be addressed on all fronts: judicial, legislative and executive.'
# 327 'In addition, I again raised climate. I believe this is doing good, so will remain on council &amp; keep at it. Doing otherwise would be wrong.'
# 328 "At my request, the agenda for yesterday's White House meeting went from not mentioning the travel ban to having it be first and foremost"
# 329 "@PeterGleick @business First I've heard of this meeting. Will find out why."
# 330 '@OfficeOfOMAR maybe'
# 331 "Video of MIT's entrant into the SpaceX Hyperloop competition. Air has been removed from the  Hyperloop tube to almo\xe2\x80\xa6
# 332 '@mcun1 Yes. Green cards &amp; dual citizens already ok. Work &amp; spousal visas not yet, but hopefully soon. This is separate from judicial action.'
# 333 'There has already been and there will be progress on this matter'
# 334 'Regarding the meeting at the White House:
# 335 '@lotte__world yes'
# 336 " @WIRED: The AI that beat the world's best poker players mimicked human intuition in a way no other machine ever had
# 337 "@SarahFKessler @qz Headline &amp; article is misleading. I said it won't be retracted (ie withdrawn by Pres). It may be\xe2\x80\xa6
# 338 '@ReesAndersen @FLIxrisk Yes, I believe that is critical to ensure a good future for humanity'
# 339 'Top AI researchers agree on principles for developing benefical AI
# 340 '@inhaleray I agree with creating great jobs, restoring US strength as a great manufacturer of products and anything\xe2\x80\xa6
# 341 '@mcwm @jackclarkSF Yeah, sorry about that :)'
# 342 '@JacobofAmber Yes, the order is still bad, but it is always important to read the source material'
# 343 "Reading the source material is better than reading other people's opinions about the source material
# 344 " @Hyperloop: Congrats to WARR Hyperloop team for fastest pod--flew down entire length of track at the world's first Hyperloop competition\xe2\x80\xa6"
# 345 ' @Hyperloop: Watch live replay now of both MIT and WARR Hyperloop test flights at   #breakapod
# 346 ' @Hyperloop: Watchlive now at  as WARR Hyperloop team attempts their first flight in the @SpaceX Hyperloop test tr\xe2\x80\xa6'
# 347 '@danahull Strategic &amp; Policy Forum'
# 348 '@danmoran3 @redletterdave Exactly. There is no possibility of retraction, but there is possibility of modification.\xe2\x80\xa6
# 349 'Please read immigration order. Lmk specific amendments. Will seek advisory council consensus &amp; present to President.
# 350 '@ParParV It is not'
# 351 "Many people negatively affected by this policy are strong supporters of the US. They've done right,not wrong &amp; don't deserve to be rejected."
# 352 'The blanket entry ban on citizens from certain primarily Muslim countries is not the best way to address the country\xe2\x80\x99s challenges'
# 353 '@MiguelGamino @PopSci This is silly. If adding lanes actually did make it worse, that would imply removing lanes ma\xe2\x80\xa6
# 354 'And we start digging the tunnel tonight
# 355 " @techinsider: Here are all the futuristic pods competing in Elon Musk's Hyperloop competition this weekend
# 356 'Hyperloop pod race happening this weekend at SpaceX HQ (near LAX). We built a ~mile long vacuum tube on our campus big enough to fit people.'
# 357 "@suzie_official Yeah, am hearing this from a lot of people &amp; it's getting me down. I'm just trying to make a positi\xe2\x80\xa6
# 358 ' @Hyperloop: Teams arrive today for Testing Week before first-ever Hyperloop Competition at @SpaceX HQ on Jan. 27-29 \xe2\x86\x92
# 359 ' @Gizmodo: A brief chat with Elon Musk about climate change, Rex Tillerson, and Donald Trump
# 360 "@TheSkinsFactory Earthquakes tend to have the biggest effect on the surface, like waves on water. That's why LA can\xe2\x80\xa6
# 361 '@_wsimson Starting across from my desk at SpaceX. Crenshaw and the 105 Freeway, which is 5 mins from LAX'
# 362 '@clay_ellis Yup'
# 363 '@BelovedRevol Maybe next month'
# 364 'Sigh'
# 365 '@TheSammyyyD For now'
# 366 ' @NASA: #Mars is hard, but it\xe2\x80\x99s worth the risks to extend humanity\xe2\x80\x99s frontier beyond Earth. Learn about our neighbor planet:
# 367 'Here is how to vote your Tesla and SolarCity shares:
# 368 'Playing Amish Paradise in my Tesla'
# 369 '@MikeMfknSplain hmmm'
# 370 '@MacTechGenius @John_Gardi no'
# 371 ' @TeslaMotors: Tesla and Panasonic to collaborate on photovoltaic cell and module production in Buffalo, New York
# 372 ' @TeslaMotors: Additional information on a combined Tesla &amp; SolarCity
# 373 ' @ElectrekCo: Bob Lutz compares Tesla to socialism after GM took $11B from taxpayers under his\xc2\xa0reign
# 374 ' @TechCrunch: Musk on Tesla Network: "It\'s not Tesla vs\xe2\x80\xa4 Uber, it\'s the people vs\xe2\x80\xa4 U...  by @etherington
# 375 'Tesla drives itself (no human input at all) thru urban streets to highway to streets, then finds a parking spot
# 376 " @tsrandall: Tesla's new Easter egg makes the world's fastest car even faster
# 377 'Moving the Tesla announcement to Wednesday. Needs a few more days of refinement.'
# 378 'Vote tally shows ~85% of unaffiliated shareholders in favor of the Tesla/SolarCity merger! Thanks for believing.'
# 379 ' @verge: Can you spot the self-driving cameras on this Tesla Model S?
# 380 'Tesla self-driving AI with the Benny Hill option package
# 381 ' @TeslaMotors: Survey shows Tesla owners in Germany understand the meaning and function of Autopilot
# 382 'Tesla receives highest owner satisfaction score of any carmaker in Consumer Reports survey
# 383 ' @tsrandall: Tesla\xe2\x80\x99s Autopilot vindicated in NHTSA probe that shows a 40% drop in crashes
# 384 "@TeslaMotors Tesla's approach to building an autonomy platform is focused on high compute efficiency machine learni\xe2\x80\xa6
# 385 " @TechCrunch: Watch Tesla Model S P85D's instant speed avoid a potential rear-end collision  by @etherington
# 386 "Institutional Shareholder Services, world's top independent evaluator, recommends in favor of Tesla-SolarCity merger
# 387 'Will post video of a Tesla navigating a complex urban environment shortly. That was what took the extra couple of days.'
# 388 "Giant X made of Model X's by Tesla owners in China!
# 389 '@adrianvolts @TeslaMotors @TeslaMotorsClub @Teslarati Tesla software team is working seven days a week to complete\xe2\x80\xa6
# 390 ' @ElectrekCo: Right-wing group led by Trump propagandist launches campaign against Elon Musk, Tesla and SpaceX  ht\xe2\x80\xa6'
# 391 ' @TeslaMotors: All Teslas in production now have Full Self-Driving hardware, this will include Model 3
# 392 'Tesla expects to demonstrate self-driven cross-country trip next year  via @WSJ'
# 393 ' @BBC_TopGear: Meet the Tesla race car that\xe2\x80\x99ll do 0-62mph in 2.1 seconds
# 394 'Tesla Autopilot vision neural net now working well. Just need to get a lot of road time to validate in a wide range of environments.'
# 395 '@dtweiseth Tesla will never stop innovating. People are buying the wrong car if they expect this. There will be maj\xe2\x80\xa6
# 396 '@davidtayar5 Tesla will def absorb SolarCity debt. Altho extremely unlikely, I would pay it personally if need be. Debts must be honored.'
# 397 ' @ElectrekCo: Tesla Autopilot\xe2\x80\x99s new radar technology predicts an accident caught on dashcam a second later
# 398 '@trevoclark Good point. 2.34 would be a production Tesla. Stripped down, maybe as low as 2.1.'
# 399 'Tesla does 0-60 mph in 2.7 seconds in the rain  via @electrekco'
# 400 ' @TeslaMotors: "Tesla\xe2\x80\x99s announcement marks a turning point in the race towards fully autonomous vehicles." @FortuneMagazine
# 401 'Tesla announcement goes live at 5pm California time. 30 minutes of media Q&amp;A to follow.'
# 402 ' @TeslaMotors: This island in American Samoa now runs on nearly 100% solar energy thanks to 5,300+ solar panels &amp; 60 Tesla Powerpacks htt\xe2\x80\xa6'
# 403 'Report highlight: \xe2\x80\x9cThe data show that the Tesla vehicles crash rate dropped by almost 40 percent after Autosteer installation.\xe2\x80\x9d'
# 404 " @TeslaMotors: Tesla Advanced Automation Germany to make our factories, the machine that makes the machine, world's most advanced
# 405 'Exciting progress on the tunnel front. Plan to start digging in a month or so.'
# 406 'Rex Tillerson supports a carbon tax. This is what is really needed to move the needle.
# 407 ' @Gizmodo: Why it matters that human poker pros are getting trounced by an AI
# 408 "@MichaelEMann I'm just saying that we should see what happens first. The actions may be surprising."
# 409 "@MichaelEMann No they don't"
# 410 '@Nivo0o0 Was wondering what those were'
# 411 '@Michael_McLean That may be a difficult award to decline'
# 412 'Tillerson also said that \xe2\x80\x9cthe risk of climate change does exist\xe2\x80\x9d and he believed \xe2\x80\x9caction should be taken"'
# 413 '@TheEconomist ... on how to address threats of climate change. They do require a global response."'
# 414 '@TheEconomist Tillerson at his confirmation hearing: "I think it\xe2\x80\x99s important that the United States maintain its se\xe2\x80\xa6
# 415 '@redletterdave Ok, fine. Soldier 76. My dark secret is out ...'
# 416 "@danahull I share The Economist's opinion that he should be given the benefit of the doubt unless his actions prove otherwise"
# 417 '@danahull Rex is an exceptionally competent executive, understands geopolitics and knows how to win for his team. His team is now the USA.'
# 418 '@TheEconomist This may sound surprising coming from me, but I agree with The Economist. Rex Tillerson has the poten\xe2\x80\xa6
# 419 '@dean_arexding There will be a software update this weekend that improves self-calibration ability'
# 420 ' @neiltyson: In 1927 Lindbergh flew from NY to Paris. 45 yrs later, in 1972 we last walked on the Moon. 45 yrs later, in 2017 we\xe2\x80\xa6 we\xe2\x80\xa6 we\xe2\x80\xa6'
# 421 '@tsrandall 3 months maybe, 6 months definitely'
# 422 '@stephenstohn Yes, safety should improve significantly due to autonomy features, even if regs disallow no driver present'
# 423 'Auto steer limited to 45 mph on highways for now, i.e. heavy traffic, where it is needed most. Limit will raise as we get more data.'
# 424 '@dnansink40 Autonomy capability should improve via OTA every 2 to 6 weeks'
# 425 "@HendrikStruik The 100D price takes into account exchange rate shifts, whereas other vehicle prices haven't yet been adjusted"
# 426 '@gdoehne @reddit Yes. Block 5 is the final upgrade of the Falcon architecture. Significantly improves performance &amp;\xe2\x80\xa6
# 427 '@dtweiseth If we applied resources to doing super complex retrofits, our pace of innovation would drop dramatically'
# 428 '@RitaChung16 Yes'
# 429 '@VinnyLingham Unfortunately, that would require stripping down the entire car and replacing 300+ parts. Wish there was an easy way.'
# 430 '@gdoehne Expendable. Future flights will go on Falcon Heavy or the upgraded Falcon 9.'
# 431 "@jakebathman Car won't complete camera calibration. Working on software solution to adjust image crop dynamically,\xe2\x80\xa6
# 432 'Autopilot for HW2 rolling out to all HW2 cars today. Please be cautious. Some cars will require adjustment of camera pitch angle by service.'
# 433 'Validating a GPU driver fix and camera pitch angle health check for HW2'
# 434 '@UKPJD Similar to SpaceX, the T is like a cross section of an electric motor, just as the X is like a rocket trajectory'
# 435 '@TOCHOTE Our target is a 90% reduction with HW2 as the software matures'
# 436 '@cameronrad Not specifically, but there have been several incidences of pedestrian and bicyclist lives saved by Autopilot'
# 437 '@ModularLifeSys @NHTSAgov It might. Am not sure.'
# 438 '@gavinnwaters Looking good so far. Should roll out this weekend.'
# 439 'Final report on Autopilot issued by @NHTSAgov is very positive
# 440 '@visakanv One million'
# 441 ' @SpaceX: Updated launch and landing photos \xe2\x86\x92
# 442 'Falcon before launch
# 443 '@FellipeC Not the ideal ending'
# 444 '@OlivierW4 There will be many improvements to HW1 over the course of the year'
# 445 '@craighamnett Yes'
# 446 '@Brian_Ashcraft Yeah, it has a lot of potential'
# 447 'Rewatched "Ghost in the Shell" and the end of "Colossus: The Forbin Project"
# 448 'HW2 Autopilot now downloading to all HW2 cars, but in non-actuating mode to assess reliability. If looks good, actuation by end of week.'
# 449 '@JimDeKort @SpaceX Rotates 180 degrees and does a retro burn'
# 450 '@JimDeKort @SpaceX It does'
# 451 'Liftoff
# 452 ' @SpaceX: First stage has landed on Just Read the Instructions
# 453 'All satellites deployed'
# 454 'Mission looks good. Started deploying the 10 Iridium satellites. Rocket is stable on the droneship.'
# 455 ' @SpaceX: Less than 1 hour until Falcon 9 launch of 10 @IridiumComm NEXT satellites. Instant launch window opens at 9:54am PST
# 456 " @SpaceX: Tracking ground wind for tomorrow's launch attempt of 10 @IridiumComm NEXT satellites. Weather overall 60% favorable
# 457 ' @TeslaMotors: Building the Supercharger Network for the Future
# 458 '@brandonr182 @sama Have you tried steam engines? They are amazing.'
# 459 '@MotorTrend Sarah should be in contact with you soon about doing a benchmark test'
# 460 '@gurnam @brianstucki @reddit It is'
# 461 '@JRMYGRNBRGR Hopefully, early next week. Results from limited release look good so far. Trying our best to be super careful.'
# 462 '@robsmallshire @ClareMacraeUK It will'
# 463 'Promising early results from the Ludricrous Easter egg. Looks like 0 to 60 mph in 2.34 sec (Motor Trend spec) might be achievable...'
# 464 '@mjreddyMD If the results look good from the latest point release, then we are days away from a release to all HW1\xe2\x80\xa6
# 465 "@redletterdave The least cool characters...it's embarrassing"
# 466 '@mbhnyc It will in an upcoming release later this year'
# 467 ' @TeslaMotors: Welcome Chris Lattner
# 468 '@matt_mantyla @TeslaMotors Increasing capacity at existing Supercharger locations now has top priority. Some are ov\xe2\x80\xa6
# 469 '@OlivierW4 Longitudinal control will, but lateral (steering) control will cap at 35 mph for a bit longer. Will rais\xe2\x80\xa6
# 470 'If all looks good, HW2 Autopilot functionality will switch from shadow to active mode by end of week for cars beyond initial 1000'
# 471 'New rev for Autopilot HW2 rolling out Mon to first 1000 &amp; to rest of fleet in shadow mode. Also improves HW1 and enables Ludicrous+.'
# 472 '@fatihorhan @SpaceX That was a great game'
# 473 '@pensasoda  via @WIRED'
# 474 'Hold-down firing of @SpaceX Falcon 9 at Vandenberg Air Force completed. All systems are go for launch next week.'
# 475 'HW2 Autopilot software uploading to 1000 cars this eve. Will then hold to verify no field issues and upload to rest of fleet next week.'
# 476 '@vicentes @DragTimes Late Jan, along with Linux kernel upgrade'
# 477 '@DragTimes Yes, but held up by Autopilot . It def works tho in shaving 0.1 sec off 0-60mph &amp; 1/4 mile. If AP goes t\xe2\x80\xa6
# 478 'Resolving an Autopilot HW2 bug that shows up when booting from a subzero cold-soak. If that fix works, software will start uploading tmrw.'
# 479 'Churchill (non) quotes \n
# 480 ' @IridiumComm: Milestone Alert: The first ten #IridiumNEXT satellites are stacked and encapsulated in the Falcon 9 fairing. #NEXTevolutio\xe2\x80\xa6'
# 481 '@andrewket Almost there. Undergoing final validation. Might go out in next few days.'
# 482 'Deus ex machina on the center screen when it ends'
# 483 '@quipme Occasional existential dread is inevitable if you think at all about the future'
# 484 "@djsearle @FredericLambert Yes, grid won't be needed for moderate use Superchargers in non-snowy regions"
# 485 "@yamenalhaddad Brain is full right now and that's a hard one"
# 486 "@ddaogaru If you don't like the P100DL, you can give it back"
# 487 '@mwangltg Yes'
# 488 '@darkdude203 It is keyed off the volume of music in the car. If you turn that down w left scroll wheel, it will be quieter.'
# 489 'Make sure your car is connected to wifi for the update. Will update over its cell connection too, but takes much longer.'
# 490 '@CJDSB Looking promising for next week'
# 491 '@jelleprins Some years away, but yes'
# 492 '@Thebeazles Night is easy. Twilight is hardest.'
# 493 '@vicentes Yes'
# 494 '@DragTimes Hoping for next week. Also going through validation.'
# 495 '@slackmds In work'
# 496 '@ChromeJS10 Should start changing soon'
# 497 'I am actually going to do this'
# 498 '@TeslaMotors We are going to modify this so that people only pay a fee if most bays are occupied. If the site is ba\xe2\x80\xa6
# 499 "Boring, it's what we do"
# 500 'It shall be called "The Boring Company"'
# 501 'Traffic is driving me nuts. Am going to build a tunnel boring machine and just start digging...'
# 502 '@loic You too :)'
# 503 ' @thedrive: These Are the Lobbyists Behind the Site Attacking Elon Musk and Tesla:
# 504 "@FredericLambert A mere 350 kW ... what are you referring to, a children's toy?"
# 505 '@FredericLambert There are some installed already, but full rollout really needs Supercharger V3 and Powerpack V2,\xe2\x80\xa6
# 506 '@wpconner Good idea'
# 507 "@SweensChris Should complete in 2017. One is def planned for Swift Current, near my cousin's wheat farm where I had my 18th bday."
# 508 '@CMaggiore50 Typing Mars after holding down the T symbol on the center console works on S and X. Also try renaming your car 42.'
# 509 'To activate the Model X holiday performance, just type holidays or ModelXmas after pressing the logo. Also, Mars.
# 510 '@pcwizardllc No major precipitating event, but people in general were going a bit too fast on winding roads'
# 511 '@pcwizardllc Will be restored soon where there is a lead vehicle, ie you are being overtaken a lot due to true traf\xe2\x80\xa6
# 512 "@vicentes That is actually rolling out to all Model X's right now"
# 513 '@SamLawrence 8.1, which hopefully goes out next week.'
# 514 'Looks like we might be ready to rollout most of Autopilot functionality for HW2 towards the end of next week'
# 515 "@loic You're right, this is becoming an issue. Supercharger spots are meant for charging, not parking. Will take action."
# 516 'Forming a rocket nozzle
# 517 'A life well lived
# 518 "How do we know this story isn't fake? Unfortunately, it is probably true.
# 519 ' @OpenAI: A video tutorial and overview of Universe from @sirajology:
# 520 " @OpenAI: We're releasing Universe, a platform for measuring and training AI agents:
# 521 'Model S smashes into semi truck trailer and lifts it off the ground. Driver walks away.
# 522 ' @TeslaMotors: "Faster than a supercar, roomier than an SUV, more eco-friendly than... anything! Rating: \xe2\x98\x85\xe2\x98\x85\xe2\x98\x85\xe2\x98\x85\xe2\x98\x85" @MailOnline
# 523 '@edwardsanchez about three weeks and it will get rolled out incrementally in monthly releases'
# 524 '@chemisdrey yes'
# 525 '@Mederinho10 @BW @business at least some of them'
# 526 "@stryker_88 That doesn't make sense. Will look into it."
# 527 '@CJDSB @TeslaMotors About 3 weeks'
# 528 '@stryker_88 Backlog of 5 seat foldflat config. 6 seat can be made earlier. Actually my fav version.'
# 529 '@YahooFinance Love the pic tho'
# 530 "Can anyone uncover who is really writing these fake pieces? Can't be skankhunt42. His work is better than this.
# 531 ' @newscientist: Google\xe2\x80\x99s DeepMind AI can lip-read TV shows better than a pro
# 532 '@itsjasonwhite @TeslaMotors perfect'
# 533 'Longer version of self-driving demo with Paint It Black soundtrack \n
# 534 '@veritasDK @TeslaMotors That and Paint It Black will both be uploaded for free as Easter (holiday?) eggs'
# 535 '@wheelsupgal @TeslaMotors yes'
# 536 '@ParParV -2'
# ...
# 2665 'Will publish something on the Hyperloop in about four weeks. Will forgo patents on the idea and just open source it. Not a vac tunnel btw.'
# 2666 '"Most of us live in a semi-somnambulistic state &amp; the days fly by. The 2 exceptions are childhood and when we are in love." - RG'
# 2667 'Headed to a (ahem) volcano caldera. Since I didn\'t finish my PhD, it\'s actually "Mr." Evil.
# 2668 '@n23mc I think we will see people on Mars in less than 20 years. 12 to 15 years most likely. #OccupyMars'
# 2669 'Going at full speed! MT \xe2\x80\x9c@iansomerhalder: Elon- you are my hero my friend.Please!Ramp up production on cars that use NO gas."'
# 2670 'Now back to work. Intense months ahead as we ramp production of rockets and cars.'
# 2671 "Moonbow's are real, btw. I'm not on acid :) Here is what we saw:
# 2672 'Am standing on the beach in Maui and looking at a moon rainbow for the first time in my life. Incredibly beautiful.'
# 2673 'Screening of Baseball in the Time of Cholera (dir: @brynmooser @daviddarg, prod @oliviawilde &amp; me) at WME July 12. @rainnwilson hosting'
# 2674 "Thanks Dan, you are a good sportsman. I will still donate to DWB as though I'd lost.
# 2675 ' @SpaceX: "This Is Our Planet" time-lapse video
# 2676 '"The Girl Who Fixed the Umlaut" @NewYorker
# 2677 'She was a great woman \xe2\x80\x9c@VanityFair: In Memoriam, Nora Ephron, 1941-2012
# 2678 ' @estiloygracia: When it comes to loving someone, you either never did or always will. @VanityFair'
# 2679 'Meant to post this link for Merlin:
# 2680 'Merlin fired at full thrust! Engine weighs half a ton, but has power equal to several Hoover Dams
# 2681 'Model S review by Motor Trend
# 2682 'About to deliver the first ten Model S cars from @TeslaMotors!'
# 2683 '@RichardGarriott Dragon will use four pairs of side mounted Superdraco engines. Can function with up to four out.'
# 2684 'Just fired our Superdraco escape rocket engine at full thrust! Needed to carry astronauts on Dragon
# 2685 "Wore Marquis de Sade outfit for a party last night. Was v popular with women who'd read 50 Shades :)
# 2686 '"Any sufficiently advanced technology is indistinguishable from magic" - Arthur C Clarke. Thanks for the quote, RIP.'
# 2687 'While in Austin, had a great time doing a cameo in @rodriguez latest movie, Machete Kills. Cool studio on old airport.'
# 2688 'Spacecraft arrives at Port of Los Angeles for transfer to SpaceX test facilities in Texas
# 2689 'Dragon floating in the Pacific near California. Reentry scorch marks visible on the heat shield
# 2690 'Splashdown successful!! Sending fast boat to Dragon lat/long provided by P3 tracking planes #Dragon'
# 2691 'Thrusters will also fire during reentry to adjust touchdown point. Next version will land w helicopter precision #Dragon'
# 2692 'Spaceship has departed from the International Space Station. Firing thrusters to deorbit in ~30 mins #Dragon'
# 2693 'Space Station tracking spaceship docking approach vector  #Dragon
# 2694 'Dragon captured by the International Space Station! Just awesome ...
# 2695 'Dragon flies over the SpaceX #GrasshopperProject at our central Texas test site. It will jump soon.
# 2696 'The head of the Russian Space Agency and some Russian diplomats are visiting @SpaceX today. Looking forward to meeting.'
# 2697 ' @SpaceX: #Dragon spacecraft is now visible from the space station as a small dot.
# 2698 'About 110 miles away and the spacecraft is now in direct communication with the Space Station #Dragon'
# 2699 'The President just called to say congrats. Caller ID was blocked, so at first I thought it was a telemarketer :)'
# 2700 'Dragon fly by of Space Station planned for 12:47 am California time. All systems green. #dragonlaunch'
# 2701 'Interview in Nature describing why we should extend life to Mars
# 2702 'Judge dismisses lawsuit to take the happy out of "Happy Meal"
# 2703 'Huge tornadoes in Texas tossing truck trailers through the air. Hope people are ok.
# 2704 "Also dig Mass Effect. It's all fun & games until the AI decides people suck. Maybe we can be their limbic system."
# 2705 'Bioshock is an Ayn Rand dystopia and Fallout New Vegas is a Hegelian dialectic. Games have come a long way since Pong.'
# 2706 'UN must take responsibility & help people of Haiti. MT "@brynmooser: Front page NYTimes.  \n
# 2707 'Happy bday to my old and dear friend @adeoressi! U do parties better than a rockstar. For Berlin ...
# 2708 'The Model S beta endurance car just passed 150,000 miles on a single battery pack!'
# 2709 'Interesting interview with Vinge about superhuman AI and optimistic apocalypses
# 2710 'Support @Polar_Broadband as they try to save a good satellite from becoming space junk. Let it live!  #antarctica'
# 2711 ' @SpaceX: In case you missed it, here is the full video of SpaceX on @60Minutes last night. What did you think of the story?  ...'
# 2712 'Lovely poster about wishes that explains one of the many reasons to make life multiplanetary
# 2713 '10 years ago today, SpaceX was founded. Many battles fought. Physics always won.
# 2714 "Why I'm leaving the Empire, by Darth Vader
# 2715 'If something is physically possible, not only is someone doing it, but there is also an award show.'
# 2716 'Mountain lions eat cats, which means we *actually* live in a cat eat cat world ... an apology is owed to dogkind!'
# 2717 'I think if you go there, they just feed you delicious candy all day and ask nothing in return.'
# 2718 'Just passed a place called the Sugar Shack in a Louisiana swamp. I wonder what happens there?
# 2719 ' @westcoastbill: lol my friends car \xe2\x80\x9c@ryan: See also:
# 2720 'Dawn at Cape Canaveral
# 2721 "@TomMao1 Studied physics in college, read a lot of books and was taught by the world's leading domain experts at SpaceX."
# 2722 ' @timminchin: A really clear and concise article debunking climate science sceptics. Please read & .
# 2723 'Falcon 9 and Dragon now vertical on the launch pad, surrounded by 300 ft tall lightning towers
# 2724 '@LooperNor Yes, this will, if all goes well, be the first commercial spaceship to dock with the Space Station. T zero ~ end of April.'
# 2725 'Dragon spaceship and Falcon 9 rocket just completed final assembly at Cape Canaveral
# 2726 'Iran\'s nuclear weapons facility is apparently called "Frodo". Watch out for Gollum! My precious...
# 2727 'Important point highlighted by @kqed: an electric car in California produces only 1/4 CO2 of gasoline
# 2728 'Model X review by Jim Motavalli. I think he likes the car.
# 2729 ' @nybooks: \xe2\x80\x9cLike a serpent among roses, like an asp / Among withered thornapples I coil to / And at you.\xe2\x80\x9d
# 2730 'At the Samovar having tea called "monkey picked iron goddess of mercy". Those monkeys sure know their tea.
# 2731 'Do not search for purple squirrels! Giving them attention only makes them want to be more purple.'
# 2732 "@TeslasBigFan Don't worry, we've got a cool solution for ski storage on the X with the Falcon wing doors"
# 2733 'Btw, Foster the People is playing the Model X event tonight. Seemed like the right vibe.'
# 2734 'Model X sketch showing just a bit more leg. Unveiling tonight...
# 2735 ' @SpaceX: Photo Update: Dragon complete with trunk at the SpaceX hangar, preparations continue for the historic mission ahead.  ...'
# 2736 "Russia and China are blocking UN action. Can't imagine why they wouldn't support a democratic uprising..."
# 2737 'Wish there was something we could do to help the people of Syria.
# 2738 '@BenToBeWild Yes, we will unveil a fully functional advanced prototype of the Model X -- almost identical to production.'
# 2739 'The sheer size of Falcon Heavy is mind-blowing. It could literally send a fully loaded London bus to the moon.'
# 2740 'The London Sunday Times created a chart showing how Falcon compares to the Saturn V and Shuttle
# 2741 'Just posted a photo
# 2742 '@MacDeviant Yeah, we will stream the whole mission realtime with no buffer. You see what we see.'
# 2743 'Docking with Space Station now likely to happen in April. Hopefully will look something like this:
# 2744 'The most interesting view of the Model X is really with the doors open
# 2745 'Just test-fired the Superdraco rocket engine. Enables launch escape and landing on thrusters. SpaceX.com
# 2746 'Um, while awesome in its own way, that was not actually the SpaceX theme song. It seems that irony is sometimes lost in a tweet.'
# 2747 'The SpaceX theme song by Total Ghost is just too good ... ooh ooh ooh
# 2748 'The lady doth protest too little.
# 2749 'The Model X unveiling will be webcast live on  at 8pm on Feb 9th. Most cars are pretty blah. This is not.'
# 2750 'Rough cut simulation of the SpaceX next gen rocket & spaceship design
# 2751 'Design completed for bringing rocket back to launchpad using only thrusters. Yay. Wings r just dead weight in space.'
# 2752 'Strongest solar radiation storm in 7 years is blasting Earth. This huge eruption hits us tomorrow:
# 2753 'Bought some wood and built a little treehouse with my boys. Few more beautiful ways to spend an afternoon.'
# 2754 '@TheOnion I heard Lars von Trier optioned the movie rights'
# 2755 ' @SpaceXer: Inside the SpaceX Rocket Factory. Take a look with @PopMech
# 2756 'That said, even though they cause me grief, I would defend the right of shorts to exist. They are often unreasonably maligned.'
# 2757 'TSLA down ~$500M Friday, but back up ~$500M today. Sorry for the roller coaster.'
# 2758 'Somebody needs to tell Kim Jong-un that the showbiz phrase "break a leg" doesn\'t mean what he thinks it does'
# 2759 'Once more, with feeling!  "North Korea Punishes Insincere Mourners"
# 2760 'Kids these days are so grown up!  "Second-Graders Wow Audience With School Production Of Equus"
# 2761 'Model S Performance powertrain produced so much torque today that we broke the dyno. 4.4 sec 0-60 mph will not be a problem.'
# 2762 'Model S Signature series sold out as of today
# 2763 'Next month is also when our Dragon spaceship docks with the Space Station for the first time. Major pucker factor...'
# 2764 'Feb is huge month. Model X world premier and public reveal of our LA design studio on the 9th. Stay tuned for more details.'
# 2765 "Just finished Massie's book on Catherine. An amazingly expansive and compelling portrait of an incredible woman. Highly recommend."
# 2766 "@om Respectfully disagree. Larry  made awesome moves last year, which laid the foundation for G+ to kick butt in 2012. He's a stud."
# 2767 "What everyone really thinks ...  \xe2\x80\x9c@jonlovett: If Mayans were good at predicting the future, there'd be Mayans.\xe2\x80\x9d"
# 2768 'On a lighter note, the RHCP are f* awesome. No better way to bring in the New Year...
# 2769 'I said *information* weapons for a reason. The bit is mightier than the bomb.'
# 2770 "If we are not careful, we will find that knife against liberty's neck. Fate has a great sense of irony.
# 2771 'We built powerful information weapons to fight enemies of liberty. Now those enemies are largely defeated, but the weapons remain.'
# 2772 "@FareedZakaria However, China's real estate crisis will explode in a way that makes ours look puny. They can't hide it for much longer."
# 2773 "@FareedZakaria Yeah, 2012 will be great for the American economy & jobs, as we've mostly dealt with the overbuilt housing crisis."
# 2774 'My first prediction of 2012 has come true: ouch, my head hurts.'
# 2775 "World violence being super low is probably counter-intuitive to most people. That's because modern media is a misery microscope."
# 2776 "Here's a happy thought for 2012: world violence is at an all time historical low. Excellent piece by Stephen Pinker
# 2777 'Not that this really matters. All current rocket tech, including ours, sucks. Only when it becomes fully reusable, will it not suck.'
# 2778 'SpaceX has Boeing, Lockheed, Europe (Ariane) and Russia (Proton/Soyuz) near checkmate in rocket technology. End game is all about China.'
# 2779 'China unveils ambitious space strategy
# 2780 'To be clear, CtG absolutely did *not* bang her horse. They were just close friends who liked to take showers together and spoon at night.'
# 2781 'Right mood, scented candles, Barry White singing "Can\'t Get Enough of Your Love, Baby" and the magic (by that I mean horsef*ing) happens ...'
# 2782 "I'm just saying that u shouldn't pass judgment based on one night of passion. Sometimes things just happen and u go with the moment :)"
# 2783 "Sew one button, doesn't make u a tailor; cook one meal, doesn't make u a chef; but f* one horse and u r a horsef*er for all of history..."
# 2784 "Am reading Robert Massie's book on Catherine the Great. Yeah, I know what you're probably thinking ... did she really f* a horse?"
# 2785 'Am not saying that is *necessarily* good or bad, but reality will force us to live with the consequences of our actions
# 2786 "Interesting Economist article about how humanity's collective actions have created a fundamentally new geological age -- the Anthropocene."
# 2787 '@om Cool personal essay. It really resonated with me, as I felt the same way after coming very close to dying from malaria ten years ago.'
# 2788 '@richardbranson Liked "Screw Business as Usual" a lot. This approach should be taken to heart by all, as it really is the smart move.'
# 2789 '@kanyewest Just returned from Haiti. For those who want to help, I recommend donating to MSF, UNICEF and Artists for Peace & Justice.'
# 2790 ' @TheOnion: Any Idiot Could Have Come Up With The Car  #OnionInnovation'
# 2791 '@TheOnion So true :)'
# 2792 'If you ever wanted to know the *real* truth about the moon landings ...(best Onion article ever)
# 2793 ' @TheOnion: Vending Machine Attendant Admits B3 Selection Has Changed A Lot Over The Years  #OnionInnovation'
# 2794 'Walked around a neighborhood recently rebuilt with help from APJ and others
# 2795 "It was Xmas, so we brought presents for the kids at the orphanage. They don't usually get much.
# 2796 'Met with UNICEF, Doctors Without Borders and Artists for Peace & Justice. I support them and would recommend others do too.'
# 2797 'Just returned from a trip to Haiti. Covered a lot of ground and saw many tough situations. They need a lot of help.'
# 2798 'Single character Tweets are the ulitmate extension of the Twitmeme...'
# 2799 'I'
# 2800 'The Russians are having some challenges with their rockets. Too many of the engineers that designed them have retired:
# 2801 'We had a long and interesting conversation on many subjects. He has exciting ideas for extending his creative talents beyond music.'
# 2802 'Kanye stopped by the SpaceX rocket factory today.
# 2803 'Model S options are out! Performance in red and black for me.  I will deliver my car in June/July.
# 2804 "Hi, I'm Art Garfunkel. Have you heard the sound of silence? Because, you know, it makes a sound...
# 2805 'Raul Campos invited me to do a guest DJ gig on KCRW.  Hear my random holiday season music selections at
# 2806 'Yum! Even better than deep fried butter:
# 2807 'Yeah, this really is me, as my Mom @mayemusk will attest.\nNot sure I can handle just doing 140 char missives. Will put longer thoughts on G+'
# 2808 'Got called randomly by Kanye West today and received a download of his thoughts, ranging from shoes to Moses. He was polite, but opaque.'
# 2809 'His singing and acting talent will be sorely missed:   Park sequel coming soon...'
# 2810 "Why does the crowd cry over the glorious leader Kim Il Sung's death?  Fear of being shot may play a role:
# 2811 'Sam Harris also wrote a nice piece on the awesomeness of Hitchens:  May the good man RIP.'
# 2812 'Read "Lying", the new book by my friend Sam Harris.  Excellent cover art and lots of good reasons not to lie!'
# 2813 'Am reading a great biography of Ben Franklin by Isaacson. Highly recommended.'
# 2814 'That was a total non sequitur btw'
# 2815 'Great Voltaire quote, arguably better than Twain. Hearing news of his own death, Voltaire replied the reports were true, only premature.'
# 2816 'I made the volume on the Model S  go to 11.  Now I just need to work in a miniature Stonehenge...'
# 2817 "Went to Iceland on Sat to ride bumper cars on ice!  No, not the country, Vlad's rink in Van Nuys. Awesome family fun :)

# %% [markdown]
# We can also use the scikit-learn library to do the retrieval.

# %%
new_features = tfidf.transform([query])

cosine_similarities = linear_kernel(new_features, corpus_tf_idf).flatten()
related_docs_indices = cosine_similarities.argsort()[::-1]

topk = 5
print('Top-{0} documents'.format(topk))
for i in range(topk):
    print(i, original_documents[related_docs_indices[i]])
# Out:
# Top-5 documents
# 0 '@ashwin7002 @NASA @faa @AFPAA We have not ruled that out.'
# 1 "SpaceX could not do this without NASA. Can't express enough appreciation.
# 2 '@NASA launched a rocket into the northern lights
# 3 'Whatever happens today, we could not have done it without @NASA, but errors are ours alone and me most of all.'
# 4 ' @NASA: Updated @SpaceX #Dragon #ISS rendezvous times: NASA TV coverage begins Sunday at 3:30amET:  Grapple at  ...'
