# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from sklearn.decomposition import PCA as sklearnPCA

# %%
df = pd.read_csv("wine.data.csv")

# %%
# Remove 1st column
df = df.drop('Label', axis=1)

# %%
pd.plotting.scatter_matrix(df, alpha=0.2, figsize=(10,10))
plt.show()

# %% [markdown]
# <b> What is the conclusion for the above scatter plots? </b>
#
# The scatter plot matrix appears to show lots of clusters in the data. They all appear to look slightly different (some look more linear like the Flavonius and Total pheonols scatters). From the histograms it looks like the data isn that normally distributed.

# %%
# HEAT MAP

# %% [markdown]
#  <b>Can you find any pairs of attributes which have large correlation?</b>
#
# It appears that the variables 'Total phenols' and 'Flavanoids' have the highest correlation. It also appears that 'Flavanoids' and 'OO280' have the second highest correlation of 0.79.

# %%
# Normalising the data
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaler.fit(df)
x_scaled_array = scaler.transform(df)
normalized_data = pd.DataFrame(x_scaled_array, columns=df.columns)

# %%
# kMeans clustering of normalized data
from sklearn.cluster import KMeans

seed = 123

k_means_clustering = KMeans(n_clusters=3, random_state=seed)
res = k_means_clustering.fit_predict(normalized_data)
